# %%
1.
* = operator
'hello'= string
-87.8  = float
-      = operator
/      = operator
+      = operator
6      = integer

# %%
2.
variables are used to store a data and string is what type of data 
stored in the  variable

# %%
3.
#list
a =[123,34,"mango"]
type(a)
# Out:
# list

# %%
#dictionary
a = {'A' :3 ,'b' :6 }
type(a)
# Out:
# dict

# %%
#set
a ={2,5,3}
type(a)
# Out:
# set

# %%
4.
expressions represent something like numbers,string,values
expressions have operations like addition,subtraction

# %%
5.
assignment statements doing creating variable and display  the
value and the expression is evluavate the given value

# %%
6.
bacon = 22
bacon +1
# Out:
# 23

# %%
7.
'spam'+'spamspam'
'spam'* 3
# Out:
# 'spamspamspam'

# %%
8.
Because variable naming have some conditions like first letter 
must be a character or start with underscore
therefore egg is a valid name and 100 is a invalid variable
